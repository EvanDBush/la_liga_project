# %%
import pandas as pd
spain_clean_df = pd.read_csv("results/spain_clean.csv")
season_input = 2021

season_records = spain_clean_df[spain_clean_df['Season'] == season_input]
season_records
# Out:
#              Date  Season           home             visitor score  hgoal  \
# 25815  2021-08-13    2021    Valencia CF           Getafe CF   1-0      1
# 25816  2021-08-14    2021      CD Alaves         Real Madrid   1-4      1
# 25817  2021-08-14    2021       Cadiz CF          Levante UD   1-1      1
# 25818  2021-08-14    2021   RCD Mallorca          Real Betis   1-1      1
# 25819  2021-08-14    2021     CA Osasuna  Espanyol Barcelona   0-0      0
# ...           ...     ...            ...                 ...   ...    ...
# 26190  2022-05-22    2021  Real Sociedad     Atletico Madrid   1-2      1
# 26191  2022-05-22    2021       Elche CF           Getafe CF   3-1      3
# 26192  2022-05-22    2021     Granada CF  Espanyol Barcelona   0-0      0
# 26193  2022-05-22    2021      CD Alaves            Cadiz CF   0-1      0
# 26194  2022-05-22    2021     Sevilla FC     Athletic Bilbao   1-0      1
#
#        vgoal  hpoint  vpoint
# 25815      0       3       0
# 25816      4       0       3
# 25817      1       1       1
# 25818      1       1       1
# 25819      0       1       1
# ...      ...     ...     ...
# 26190      2       0       3
# 26191      1       3       0
# 26192      0       1       1
# 26193      1       0       3
# 26194      0       3       0
#
# [380 rows x 9 columns]

# %%
team_list = season_records['home'].unique()
team_list
team = 'FC Barcelona'

team_home_record = season_records[season_records['home'] == team]
team_visitor_record = season_records[season_records['visitor'] == team]
team_season_records_df = [team_home_record, team_visitor_record]

team_season_records_df = pd.concat(team_season_records_df).sort_values( by= 'Date')
team_season_records_df
# Out:
#              Date  Season                home             visitor score  \
# 25821  2021-08-15    2021        FC Barcelona       Real Sociedad   4-2
# 25827  2021-08-21    2021     Athletic Bilbao        FC Barcelona   1-1
# 25842  2021-08-29    2021        FC Barcelona           Getafe CF   2-1
# 25862  2021-09-20    2021        FC Barcelona          Granada CF   1-1
# 25870  2021-09-23    2021            Cadiz CF        FC Barcelona   0-0
# 25878  2021-09-26    2021        FC Barcelona          Levante UD   3-0
# 25885  2021-10-02    2021     Atletico Madrid        FC Barcelona   2-0
# 25895  2021-10-17    2021        FC Barcelona         Valencia CF   3-1
# 25908  2021-10-24    2021        FC Barcelona         Real Madrid   1-2
# 25915  2021-10-27    2021      Rayo Vallecano        FC Barcelona   1-0
# 25922  2021-10-30    2021        FC Barcelona           CD Alaves   1-1
# 25932  2021-11-06    2021          Celta Vigo        FC Barcelona   3-3
# 25942  2021-11-20    2021        FC Barcelona  Espanyol Barcelona   1-0
# 25954  2021-11-27    2021       Villarreal CF        FC Barcelona   1-3
# 25964  2021-12-04    2021        FC Barcelona          Real Betis   0-1
# 25977  2021-12-12    2021          CA Osasuna        FC Barcelona   2-2
# 25983  2021-12-18    2021        FC Barcelona            Elche CF   3-2
# 25992  2021-12-21    2021          Sevilla FC        FC Barcelona   1-1
# 25997  2022-01-02    2021        RCD Mallorca        FC Barcelona   0-1
# 26008  2022-01-08    2021          Granada CF        FC Barcelona   1-1
# 26028  2022-01-23    2021           CD Alaves        FC Barcelona   0-1
# 26039  2022-02-06    2021        FC Barcelona     Atletico Madrid   4-2
# 26050  2022-02-13    2021  Espanyol Barcelona        FC Barcelona   2-2
# 26061  2022-02-20    2021         Valencia CF        FC Barcelona   1-4
# 26071  2022-02-27    2021        FC Barcelona     Athletic Bilbao   4-0
# 26081  2022-03-06    2021            Elche CF        FC Barcelona   1-2
# 26089  2022-03-13    2021        FC Barcelona          CA Osasuna   4-0
# 26100  2022-03-20    2021         Real Madrid        FC Barcelona   0-4
# 26110  2022-04-03    2021        FC Barcelona          Sevilla FC   1-0
# 26122  2022-04-10    2021          Levante UD        FC Barcelona   2-3
# 26133  2022-04-18    2021        FC Barcelona            Cadiz CF   0-1
# 26140  2022-04-21    2021       Real Sociedad        FC Barcelona   0-1
# 26144  2022-04-24    2021        FC Barcelona      Rayo Vallecano   0-1
# 26150  2022-05-01    2021        FC Barcelona        RCD Mallorca   2-1
# 26159  2022-05-07    2021          Real Betis        FC Barcelona   1-2
# 26166  2022-05-10    2021        FC Barcelona          Celta Vigo   3-1
# 26178  2022-05-15    2021           Getafe CF        FC Barcelona   0-0
# 26189  2022-05-22    2021        FC Barcelona       Villarreal CF   0-2
#
#        hgoal  vgoal  hpoint  vpoint
# 25821      4      2       3       0
# 25827      1      1       1       1
# 25842      2      1       3       0
# 25862      1      1       1       1
# 25870      0      0       1       1
# 25878      3      0       3       0
# 25885      2      0       3       0
# 25895      3      1       3       0
# 25908      1      2       0       3
# 25915      1      0       3       0
# 25922      1      1       1       1
# 25932      3      3       1       1
# 25942      1      0       3       0
# 25954      1      3       0       3
# 25964      0      1       0       3
# 25977      2      2       1       1
# 25983      3      2       3       0
# 25992      1      1       1       1
# 25997      0      1       0       3
# 26008      1      1       1       1
# 26028      0      1       0       3
# 26039      4      2       3       0
# 26050      2      2       1       1
# 26061      1      4       0       3
# 26071      4      0       3       0
# 26081      1      2       0       3
# 26089      4      0       3       0
# 26100      0      4       0       3
# 26110      1      0       3       0
# 26122      2      3       0       3
# 26133      0      1       0       3
# 26140      0      1       0       3
# 26144      0      1       0       3
# 26150      2      1       3       0
# 26159      1      2       0       3
# 26166      3      1       3       0
# 26178      0      0       1       1
# 26189      0      2       0       3

# %%
team_home_points = team_home_record['hpoint'].sum()
team_visitor_points = team_visitor_record['vpoint'].sum()
team_season_points = team_home_points + team_visitor_points
    
print(f'{team}: home points: {team_home_points} away points: {team_visitor_points} total points: {team_season_points}')
# Out:
# FC Barcelona: home points: 38 away points: 35 total points: 73

# %%
team_home_goals = team_home_record['hgoal'].sum()
team_visitor_goals = team_visitor_record['vgoal'].sum()
team_total_goals = team_home_goals + team_visitor_goals

team_home_goals_allowed = team_home_record['vgoal'].sum()
team_visitor_goals_allowed = team_visitor_record['hgoal'].sum()
team_total_goals_allowed = team_home_goals_allowed + team_visitor_goals_allowed

team_goal_differential = team_total_goals - team_total_goals_allowed
    

print(f'{season_input} {team}: Goals scored: {team_total_goals} Goals Allowed: {team_total_goals_allowed} Differential: {team_goal_differential}')
# Out:
# 2021 FC Barcelona: Goals scored: 68 Goals Allowed: 38 Differential: 30

# %%
team_home_wins = team_home_record[team_home_record['hgoal'] > team_home_record['vgoal']].shape[0]
team_home_losses = team_home_record[team_home_record['hgoal'] < team_home_record['vgoal']].shape[0]
team_home_ties = team_home_record[team_home_record['hgoal'] == team_home_record['vgoal']].shape[0]

team_away_wins = team_visitor_record[team_visitor_record['hgoal'] < team_visitor_record['vgoal']].shape[0]
team_away_losses = team_visitor_record[team_visitor_record['hgoal'] > team_visitor_record['vgoal']].shape[0]
team_away_ties = team_visitor_record[team_visitor_record['hgoal'] == team_visitor_record['vgoal']].shape[0]

team_total_wins = team_home_wins + team_away_wins
team_total_losses = team_home_losses + team_away_losses
team_total_ties = team_home_ties + team_away_ties

print(f'{season_input} {team}: Total Wins: {team_total_wins} Total Losses: {team_total_losses} Ties: {team_total_ties}')
# Out:
# 2021 FC Barcelona: Total Wins: 21 Total Losses: 7 Ties: 10

# %%
team_stats = {'Team': team, 'Points': team_season_points, 'GS': team_total_goals, 'GA': team_total_goals_allowed, 'GD': team_goal_differential, 'Wins': team_total_wins, 'Losses': team_total_losses, 'Ties': team_total_ties}
team_stats
# Out:
# {'Team': 'FC Barcelona',
#  'Points': 73,
#  'GS': 68,
#  'GA': 38,
#  'GD': 30,
#  'Wins': 21,
#  'Losses': 7,
#  'Ties': 10}
